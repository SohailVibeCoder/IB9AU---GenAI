# %% [markdown]
# <a href="https://colab.research.google.com/github/SohailVibeCoder/IB9AU---GenAI/blob/main/Task_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name:** Sohail Essajee (U5757504)
#
# This task showed me that prompt engineering is not just about asking for an answer, but about constraining the model to follow the exact computational method, especially when calendar logic can easily go wrong. By explicitly forcing actual-day counting, leap-year recognition, and step-by-step payment application, I reduced the risk of the model defaulting to a simplified textbook amortization schedule. A key insight is that for finance-related reasoning, well-designed prompts need to specify both the calculation rules and the validation checks, so the model audits its own assumptions before producing the final result.

# %% [markdown]
# **Prompt into ChatGPT:**
#
# The "Date Drift" Amortization Audit: LLMs are notoriously bad at "calendar math" (e.g., calculating interest when a payment falls on a leap year, a weekend, or an irregular date). They will hallucinate a smooth "textbook" amortization table that ignores these messy realities. The Scenario: You are auditing a small business loan that has irregular payment dates. The borrower claims the bank overcharged them interest. Loan Principal: $100,000 Annual Rate: 12% (calculated daily: Balance * (0.12 / 365) * Days_Elapsed) Start Date: Jan 1, 2024 (Leap Year) Payment Log: Jan 31: $5,000 Feb 29: $5,000 (Leap Day) Mar 31: $5,000 Beware of the trap: A standard LLM prompt will assume 30 days per month or miss the Leap Day (Feb 29), leading to a wrong ending balance. give me a prompt that addresses these kind of issues and makes the LLM do the correct calender math based on the above.

# %% [markdown]
# **Chat GPT generated prompt:**
#
# You are performing an ACTUAL-DAY amortization audit. Do not use textbook monthly amortization, 30/360, equal-month assumptions, or approximations. You must do exact calendar math using the real Gregorian calendar.
#
# Task:
# Audit this loan and determine whether the interest charged is correct.
#
# Loan details:
# - Principal: $100,000
# - Annual interest rate: 12%
# - Daily simple interest formula: Interest = Balance × (0.12 / 365) × Days_Elapsed
# - Start date: 2024-01-01
# - Payment log:
#   1) 2024-01-31: $5,000
#   2) 2024-02-29: $5,000
#   3) 2024-03-31: $5,000
#
# Critical rules:
# 1. 2024 is a leap year, so February has 29 days. You must explicitly account for Feb 29, 2024.
# 2. Count the ACTUAL number of days between dates.
# 3. Do not assume every month has 30 days.
# 4. Do not smooth or regularize payment timing.
# 5. Interest accrues between each event date based on the opening balance for that interval.
# 6. For each payment date:
#    - first compute Days_Elapsed since the previous event date,
#    - then compute accrued interest for that exact interval,
#    - then apply the payment:
#      Payment applied first to accrued interest, remainder to principal.
# 7. Show every formula with numbers substituted before giving the result.
# 8. Round money to cents, but keep enough precision internally to avoid cumulative rounding errors.
# 9. Explicitly state the day counts you used for each interval before calculating anything.
# 10. Sanity-check the calendar math before finalizing.
#
# Required output format:
# A. First, list the exact day counts for each interval:
# - 2024-01-01 to 2024-01-31 = ? days
# - 2024-01-31 to 2024-02-29 = ? days
# - 2024-02-29 to 2024-03-31 = ? days
#
# B. Then produce a table with these columns:
# - Period Start Date
# - Payment Date
# - Days Elapsed
# - Opening Balance
# - Interest Formula
# - Interest Accrued
# - Payment
# - Amount to Interest
# - Amount to Principal
# - Ending Balance
#
# C. Then give:
# - Total interest charged across all three periods
# - Ending balance after the 2024-03-31 payment
#
# D. Finally, include a short “calendar audit check” paragraph confirming:
# - that 2024 is a leap year,
# - that Feb 29 was included,
# - and that no 30-day month approximation was used.
#
# Important:
# Before computing money, verify whether these day counts are correct:
# - Jan 1 to Jan 31 = 30 days
# - Jan 31 to Feb 29 = 29 days
# - Feb 29 to Mar 31 = 31 days
#
# If any of those are wrong, explain why and correct them before proceeding.
#
# Do not skip steps. Do not provide a generic amortization schedule. This is an irregular-date audit using exact actual-day accrual.

# %% [markdown]
# **LLM OUTPUT (CHATGPT)**
#
# A. **Exact day counts**
#
# Using actual calendar days, with the standard accrual convention of counting the days **between** the prior event date and the payment date:
#
# * **2024-01-01 to 2024-01-31 = 30 days**
# * **2024-01-31 to 2024-02-29 = 29 days**
# * **2024-02-29 to 2024-03-31 = 31 days**
#
# Those three day counts are **correct**.
#
# ---
#
# B. **Actual-day amortization audit**
#
# Daily rate:
#
# [
# \frac{0.12}{365} = 0.0003287671232876712328767123
# ]
#
# Payments are applied **first to accrued interest**, then the remainder reduces principal.
#
# | Period Start Date | Payment Date | Days Elapsed | Opening Balance | Interest Formula                     | Interest Accrued |   Payment | Amount to Interest | Amount to Principal | Ending Balance |
# | ----------------- | -----------: | -----------: | --------------: | ------------------------------------ | ---------------: | --------: | -----------------: | ------------------: | -------------: |
# | 2024-01-01        |   2024-01-31 |           30 |     $100,000.00 | $100,000 × (0.12/365) × 30           |          $986.30 | $5,000.00 |            $986.30 |           $4,013.70 |     $95,986.30 |
# | 2024-01-31        |   2024-02-29 |           29 |      $95,986.30 | $95,986.3013698630 × (0.12/365) × 29 |          $915.16 | $5,000.00 |            $915.16 |           $4,084.84 |     $91,901.46 |
# | 2024-02-29        |   2024-03-31 |           31 |      $91,901.46 | $91,901.4584349784 × (0.12/365) × 31 |          $936.64 | $5,000.00 |            $936.64 |           $4,063.36 |     $87,838.10 |
#
# ---
#
# ### Step-by-step formulas
#
# #### 1) 2024-01-01 to 2024-01-31
#
# Days elapsed = **30**
#
# Interest:
#
# [
# 100{,}000 \times \left(\frac{0.12}{365}\right) \times 30
# = 100{,}000 \times 0.0003287671232876712 \times 30
# = 986.3013698630137
# ]
#
# Rounded to cents:
#
# [
# \text{Interest} = $986.30
# ]
#
# Payment application:
#
# [
# $5{,}000.00 - $986.3013698630137 = $4{,}013.6986301369863
# ]
#
# So:
#
# * Amount to interest = **$986.30**
# * Amount to principal = **$4,013.70**
#
# New balance:
#
# [
# 100{,}000 - 4{,}013.6986301369863 = 95{,}986.3013698630137
# ]
#
# Rounded display:
#
# [
# \text{Ending balance} = $95{,}986.30
# ]
#
# ---
#
# #### 2) 2024-01-31 to 2024-02-29
#
# Days elapsed = **29**
#
# Opening balance (unrounded internally):
#
# [
# 95{,}986.3013698630137
# ]
#
# Interest:
#
# [
# 95{,}986.3013698630137 \times \left(\frac{0.12}{365}\right) \times 29
# = 915.1570651154063
# ]
#
# Rounded to cents:
#
# [
# \text{Interest} = $915.16
# ]
#
# Payment application:
#
# [
# $5{,}000.00 - $915.1570651154063 = $4{,}084.8429348845937
# ]
#
# So:
#
# * Amount to interest = **$915.16**
# * Amount to principal = **$4,084.84**
#
# New balance:
#
# [
# 95{,}986.3013698630137 - 4{,}084.8429348845937 = 91{,}901.45843497842
# ]
#
# Rounded display:
#
# [
# \text{Ending balance} = $91{,}901.46
# ]
#
# ---
#
# #### 3) 2024-02-29 to 2024-03-31
#
# Days elapsed = **31**
#
# Opening balance (unrounded internally):
#
# [
# 91{,}901.45843497842
# ]
#
# Interest:
#
# [
# 91{,}901.45843497842 \times \left(\frac{0.12}{365}\right) \times 31
# = 936.6395215838897
# ]
#
# Rounded to cents:
#
# [
# \text{Interest} = $936.64
# ]
#
# Payment application:
#
# [
# $5{,}000.00 - $936.6395215838897 = $4{,}063.3604784161103
# ]
#
# So:
#
# * Amount to interest = **$936.64**
# * Amount to principal = **$4,063.36**
#
# New balance:
#
# [
# 91{,}901.45843497842 - 4{,}063.3604784161103 = 87{,}838.09795656231
# ]
#
# Rounded display:
#
# [
# \text{Ending balance} = $87{,}838.10
# ]
#
# ---
#
# C. **Totals**
#
# Total interest across all three periods:
#
# [
# 986.3013698630137 + 915.1570651154063 + 936.6395215838897
# = 2{,}838.0979565623097
# ]
#
# Rounded to cents:
#
# [
# \boxed{$2{,}838.10}
# ]
#
# Ending balance after the 2024-03-31 payment:
#
# [
# \boxed{$87{,}838.10}
# ]
#
# ---
#
# D. **Calendar audit check**
#
# 2024 **is a leap year**, so **February 29, 2024** exists and was explicitly included in the second interval. The day counts used were **30, 29, and 31 actual days**, respectively. No 30-day-month shortcut, 30/360 convention, or smooth monthly approximation was used.
#
# If the bank’s ending balance or total interest differs from **$87,838.10** and **$2,838.10** under this exact method, then their calculation likely used the wrong day count or a non-actual-day convention.
