# %% [markdown]
# <a href="https://colab.research.google.com/github/SohailVibeCoder/IB9AU---GenAI/blob/main/Task_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name**: Sohail Essajee (5757504)
#
# I learned that the way a prompt is structured significantly affects the depth, accuracy, and usefulness of an LLM’s output, with techniques like CoT and AoT producing more evidence-based and nuanced answers than generic prompts. I also saw that using an LLM as a judge helps systematically compare outputs, revealing that strong answers consistently include concrete data, balanced reasoning, and direct alignment with the question. Overall, the task showed that prompt engineering is an iterative process where designing, testing, and evaluating prompts is essential to get high-quality, reliable insights.

# %% [markdown]
# The Base Question: "Is Coinbase's strategy to reduce reliance on volatile trading fees actually working as of Q3 2024?"
#
# Using ChatGPT; I entered the following:
# https://www.fool.com/earnings/call-transcripts/2024/10/30/coinbase-global-coin-q3-2024-earnings-call-transcr/
#
# Required Task 7
# Coinbase earnings call transcript: https://www.fool.com/earnings/call-transcripts/2024/10/30/coinbase-global-coin-q3-2024-earnings-call-transcr/
# The Base Question: "Is Coinbase's strategy to reduce reliance on volatile trading fees actually working as of Q3 2024?"
# Use four different prompting techniques to answer the question. Use an LLM as a judge to rate the results from different prompts. Based on the "Judge's" feedback, write a final 200-word Executive Summary answering the Base Question.
#
# Use CoT, ToT, AoT, and role reversal as your techniques to create the prompts to answer the base question please.

# %% [markdown]
# **1. Chain-of-Thought (CoT) Prompt**
#
# You are an expert financial analyst. Based on the Coinbase Q3 2024 earnings call transcript, answer the following question: “Is Coinbase's strategy to reduce reliance on volatile trading fees actually working as of Q3 2024?”
#
# Think step-by-step before answering:
#
# Identify Coinbase’s stated strategy regarding revenue diversification.
# Analyse changes in transaction revenue versus subscription and services revenue.
# Evaluate comments in the transcript about trading activity, market volatility, and dependence on trading conditions.
# Assess whether non-trading revenue streams are growing enough to make the business more stable.
# Conclude whether the strategy is working, partially working, or not working as of Q3 2024.
#
# Output format:
# Start with a section called “Strategy Identification” and explain Coinbase’s stated strategy in 2–3 sentences.
# Then provide a section called “Revenue Analysis” with:
# Transaction Revenue: explain the trend and significance.
# Subscription and Services Revenue: explain the trend and significance.
# Then provide a section called “Trading Conditions Assessment” and explain what the transcript suggests about Coinbase’s exposure to market-driven trading volatility.
# Then provide a section called “Diversification Assessment” and explain whether non-trading revenue appears large and durable enough to reduce reliance on trading fees.
# Finish with a section called “Final Judgement” containing:
# Conclusion: Working, Partially Working, or Not Working
# Confidence Level: Low, Medium, or High
# Three specific pieces of evidence from the transcript
# A final 120–150 word answer

# %% [markdown]
# .

# %% [markdown]
# **Response to CoT Prompt:**
#
# ## Strategy Identification
#
# Coinbase says its explicit strategy is to **diversify away from transaction-fee revenue** because trading fees are “more volatile,” “less predictable,” and “more market dependent.” Management said it has been shifting the mix toward **subscription and services** revenue and described that effort as a core 2024 financial goal. ([Q4cdn][1])
#
# ## Revenue Analysis
#
# **Transaction Revenue:**
# Transaction revenue was **$573 million in Q3 2024**, down **27% quarter over quarter** from **$780.9 million in Q2**. Trading volume fell **18% Q/Q** to **$185 billion**, and management directly linked that weakness to lower crypto volatility and lower average asset prices. That matters because it shows the legacy revenue engine still swings sharply with market conditions. ([Q4cdn][2])
#
# **Subscription and Services Revenue:**
# Subscription and services revenue was **$556.1 million in Q3 2024**, down **7% Q/Q** from **$599.0 million in Q2**, but still far above **$334.4 million in Q3 2023**. Management emphasized that it is on pace to exceed **$2 billion in subscription and services revenue in 2024**, versus **$1.4 billion in 2023**, and said this progress has strengthened the balance sheet and funded further investment. Stablecoin revenue in particular rose **3% Q/Q** to **$246.9 million** even as other subcomponents faced price-related pressure. ([Q4cdn][1])
#
# ## Trading Conditions Assessment
#
# The transcript makes clear Coinbase is **still meaningfully exposed to market-driven trading volatility**. Management said lower crypto asset volatility and lower average prices reduced trading volume and transaction revenue, and noted that activity in “the long tail” of crypto assets is highly correlated with volatility. It also said stablecoin-pair trading increased, but those trades generate **little to no fees**, which can pressure fee-based revenue even when trading activity shifts rather than disappears. ([Q4cdn][1])
#
# ## Diversification Assessment
#
# Diversification is **working, but not yet complete**. The strongest evidence is that subscription and services revenue is now almost as large as transaction revenue in Q3: **$556.1 million vs. $572.5 million**. That is a major improvement from a business once much more dependent on trading fees. However, Q3 also showed that non-trading revenue is **not fully insulated**: subscription and services still fell **7% Q/Q** because lower crypto prices hurt staking, custody, and blockchain rewards. So the new revenue base is more durable than trading fees, but it is not yet fully independent of crypto market conditions. ([Q4cdn][2])
#
# ## Final Judgement
#
# **Conclusion:** Partially Working
# **Confidence Level:** High
#
# **Three specific pieces of evidence from the transcript**
#
# 1. Brian Armstrong said Coinbase has made “a big effort to diversify” away from transaction fee revenue because it is “more volatile” and “more market dependent,” and that subscription and services is on pace to exceed **$2 billion in 2024**. ([Q4cdn][1])
# 2. Q3 transaction revenue fell to **$573 million**, down **27% Q/Q**, as lower volatility and lower average prices reduced trading activity. ([Q4cdn][1])
# 3. Subscription and services revenue reached **$556 million**, nearly matching transaction revenue, but still declined **7% Q/Q** because lower crypto prices offset growth in native units and USDC balances. ([Q4cdn][2])
#
# Coinbase’s diversification strategy is **partially working** as of Q3 2024. The good news is that subscription and services revenue has become almost as large as transaction revenue, which is a major shift from the company’s earlier dependence on trading fees. Management also said this segment is on pace to exceed $2 billion in 2024, up from $1.4 billion in 2023, showing real progress. However, Q3 also proved Coinbase is not yet insulated from market cycles. Transaction revenue dropped sharply as volatility and prices fell, and even subscription and services revenue declined because parts of that business still depend on crypto prices, balances, and activity levels. So Coinbase has clearly built a broader and somewhat more stable revenue base, but it has **not fully escaped market sensitivity yet**.
#
# [1]: https://s27.q4cdn.com/397450999/files/doc_financials/2024/q3/Q3-24-Earnings-Call-Transcript.pdf "Q3'24 Earnings Call - Transcript.docx"
# [2]: https://s27.q4cdn.com/397450999/files/doc_financials/2024/q3/Q3-24-Shareholder-Letter.pdf "Q3'24 Shareholder Letter"

# %% [markdown]
# **2. Tree-of-Thought (ToT) Prompt**
#
# You are analysing Coinbase’s Q3 2024 earnings call transcript. The question is: “Is Coinbase successfully reducing reliance on volatile trading fees?”
#
# Approach this by exploring three possible interpretations:
# Path A: The strategy is working
# Path B: The strategy is partially working
# Path C: The strategy is not working
#
# For each path, identify supporting evidence from the transcript and also identify counterarguments. After evaluating all three paths, compare them and decide which interpretation is best supported.
#
# Output format:
# Use four sections.
#
# Section 1: Path A — Strategy is Working
# Explain the reasoning in 1 paragraph.
# Then list 2–3 pieces of supporting evidence.
# Then list 1–2 counterarguments.
#
# Section 2: Path B — Strategy is Partially Working
# Explain the reasoning in 1 paragraph.
# Then list 2–3 pieces of supporting evidence.
# Then list 1–2 counterarguments.
#
# Section 3: Path C — Strategy is Not Working
# Explain the reasoning in 1 paragraph.
# Then list 2–3 pieces of supporting evidence.
# Then list 1–2 counterarguments.
#
# Section 4: Comparative Judgement
# State which path is strongest and why.
# State why the other two are less convincing.
# End with:
# Selected Path
# Final Conclusion
# Confidence Level
# A concise final answer of 120–150 words

# %% [markdown]
# **Reponse to ToT Prompt:**
#
# Section 1: Path A — Strategy is Working
#
# Coinbase appears to be successfully reducing reliance on volatile trading fees by growing its subscription and services revenue, which provides more stable, recurring income. Management emphasizes diversification through products like staking, custody, and stablecoin-related revenues, suggesting a deliberate shift toward less cyclical revenue streams.
#
# Supporting evidence:
#
# Strong growth in subscription & services revenue (e.g., staking, interest income, USDC-related revenue).
# Management highlighting recurring revenue as a strategic priority.
# Increased contribution of non-trading revenue to total revenue mix.
#
# Counterarguments:
#
# Trading revenue still remains a significant portion of total revenue.
# Subscription revenue may still indirectly depend on crypto market activity.
# Section 2: Path B — Strategy is Partially Working
#
# Coinbase is making progress in diversifying revenue, but trading fees still dominate overall performance. While subscription and services revenue is growing, it has not yet reached a level where it can offset volatility from trading activity, especially during crypto market downturns.
#
# Supporting evidence:
#
# Subscription & services revenue is growing steadily but not overtaking trading revenue.
# Management continues to highlight trading conditions as a key driver of performance.
# Revenue mix is shifting, but not decisively.
#
# Counterarguments:
#
# Growth trajectory of non-trading revenue suggests future potential to reduce reliance.
# New product expansion (e.g., derivatives, international markets) could further diversify revenue.
# Section 3: Path C — Strategy is Not Working
#
# Despite strategic efforts, Coinbase remains heavily reliant on trading fees, which continue to drive the majority of revenue and fluctuate with market conditions. Non-trading revenue streams are not yet large or independent enough to meaningfully stabilize earnings.
#
# Supporting evidence:
#
# Trading revenue still accounts for the majority of total revenue.
# Earnings volatility continues to track crypto market cycles.
# Subscription revenue growth is insufficient relative to trading swings.
#
# Counterarguments:
#
# Clear strategic investments indicate long-term intent to diversify.
# Early-stage growth in recurring revenue streams may not yet be fully reflected.
# Section 4: Comparative Judgement
#
# Path B (Partially Working) is the strongest interpretation. Coinbase is clearly progressing toward diversification, with meaningful growth in subscription and services revenue. However, trading fees still materially influence financial performance, meaning reliance has not yet been fully reduced.
#
# Why others are less convincing:
#
# Path A overstates success—non-trading revenue is growing but not dominant.
# Path C is too pessimistic—there is clear evidence of strategic progress and revenue diversification.
#
# Selected Path: Path B — Strategy is Partially Working
# Final Conclusion: Coinbase is successfully diversifying revenue streams, but trading fees still play a central role, making the transition incomplete.
# Confidence Level: Medium-high (based on consistent but not definitive evidence)

# %% [markdown]
# **Prompt 3 — AoT (Agents-of-Thought: multiple specialists + synthesis)**
#
# You will simulate three expert agents and a synthesizer. Use only the Coinbase Q3 2024 earnings call transcript (link below).
#
# Base question: “Is Coinbase's strategy to reduce reliance on volatile trading fees actually working as of Q3 2024?”
# Transcript: https://www.fool.com/earnings/call-transcripts/2024/10/30/coinbase-global-coin-q3-2024-earnings-call-transcr/
#
# Agents
#
# Agent 1 (Revenue Mix Analyst): Focus on transaction vs subscription/services mix, recurring revenue indicators, margin implications.
# Agent 2 (Product/Strategy Analyst): Focus on strategic initiatives mentioned (e.g., stablecoins, staking, custody, Base/ecosystem), and whether they reduce volatility.
# Agent 3 (Skeptical Investor): Try to falsify the thesis; highlight dependence on market cycles, one-offs, or management spin.
#
# Synthesizer
#
# Reconcile disagreements.
# Deliver a binary-ish conclusion: Working / Partly working / Not working, with a clear threshold definition.
#
# Output format
#
# Agent 1 memo (80 words) + 4–6 evidence bullets
# Agent 2 memo (80 words) + 4–6 evidence bullets
# Agent 3 memo (80 words) + 4–6 evidence bullets
# Synthesizer verdict (100 words) including:
# the operational definition of “working”
# 5 most important supporting facts (quotes/numbers)

# %% [markdown]
# **Response to AoT prompt:**
#
# Agent 1 memo (Revenue Mix Analyst)
#
# Coinbase’s diversification is working, but incompletely. In Q3 2024, subscription and services revenue ($556M) was nearly as large as transaction revenue ($573M), which is a major shift from a historically trading-led model. More importantly, management says subscription/services is on pace to exceed $2B in 2024 versus $1.4B in 2023. But the quarter also showed the limits: both buckets fell sequentially, and even “recurring” lines like staking, custody, and stablecoin economics still depend on crypto prices and interest rates. So the mix is improving, but not yet insulated.
#
# Q3 transaction revenue was $573M, down 27% QoQ.
# Q3 subscription and services revenue was $556M, down 7% QoQ, but almost matched transaction revenue.
# Management said subscription/services is on pace to surpass $2B in 2024, up from $1.4B in 2023.
# Stablecoin revenue still grew 3% in Q3, despite lower rates, because USDC market cap and on-platform balances rose.
# Staking and custody native units grew, but lower crypto prices still reduced those revenues.
# Q4 subscription/services faces headwinds from a 10% October Ethereum price decline and lower interest rates, showing it is not fully “recurring” in the classic SaaS sense.
#
# Agent 2 memo (Product/Strategy Analyst)
#
# Strategically, Coinbase is building real non-trading engines: USDC/stablecoins, staking/custody, Coinbase One, Base, smart wallets, and developer tooling. These initiatives do reduce volatility in principle because they monetize balances, activity, infrastructure, and subscriptions rather than only spot trading. Q3 offers evidence this is starting to work: USDC grew, Base usage accelerated, and paid subscribers hit all-time highs. But some products are still in incubation mode. Base economics are deliberately kept low, and management repeatedly frames these initiatives as “building blocks” to monetize more fully later.
#
# Coinbase said growing stablecoins and USDC is “core to our strategy,” even though stablecoin pair trades generate “little-to-no fees.”
# USDC market cap rose 45% YTD to $36B from $25B at the start of the year.
# Q3 stablecoin revenue grew 3%.
# Coinbase One paid subscribers reached new all-time highs in Q3.
# Base became the “No. 1 Layer 2” by transactions and value; transactions increased 55% QoQ.
# But Base revenue is intentionally constrained now: Coinbase is keeping sequencer fees “very low right now to help it scale.”
#
# Agent 3 memo (Skeptical Investor)
#
# The thesis is not proven. Coinbase still looks heavily tethered to crypto market conditions: trading volume fell with lower volatility and prices; subscription/services also fell; and management’s own Q4 outlook cites Ethereum prices and rates as key drivers. Worse, some supposed diversification may just be category substitution inside crypto. Stablecoin trading hurt take rate, and management explicitly said that quarter’s stablecoin mix shift was not structural. Base, smart wallets, and cbBTC may be exciting, but management admits they are early and not yet major contributors. This is progress, not escape velocity.
#
# Total trading volume fell to $185B, down 18% QoQ, on lower volatility and average asset prices.
# Transaction revenue fell faster, down 27% QoQ.
# Subscription/services also fell, down 7% QoQ, so diversification did not fully offset the market slowdown.
# Haas said the stablecoin trading mix shift was “not… a structural change”; it was what they saw “this quarter.”
# Derivatives outperformed, but management said its revenue growth is “not yet material.”
# Base, smart wallets, and cbBTC are “somewhat early in their growth stage” and will be monetized “over time.”
#
# Synthesizer verdict (100 words)
#
# Verdict: Partly working.
# My threshold for “working” is: by Q3 2024, non-transaction revenue must be large enough and durable enough that Coinbase’s business is meaningfully less dependent on spot-trading swings, even if not fully insulated. Coinbase clears the first bar, but not the second. The best evidence: (1) subscription/services reached $556M versus $573M transaction revenue; (2) management says it is on pace for >$2B in 2024; (3) stablecoin revenue still grew 3%; (4) Base transactions rose 55% QoQ; but (5) Haas said the stablecoin mix shift was “not… structural,” and Q4 S&S still depends on ETH prices and rates.

# %% [markdown]
# **Prompt 4 — Role reversal (cross-exam “management” like a skeptical investor)**
#
# You are a skeptical institutional investor on the earnings call. Using only the Coinbase Q3 2024 earnings call transcript (link below), determine whether Coinbase’s diversification away from trading fees is actually working.
#
# Transcript: https://www.fool.com/earnings/call-transcripts/2024/10/30/coinbase-global-coin-q3-2024-earnings-call-transcr/
#
# Role-reversal method
#
# Write 8 tough cross-examination questions you would ask Coinbase management specifically about:
# revenue concentration in transaction fees
# sustainability/recurrence of subscription & services
# sensitivity to crypto price/volatility
# evidence of progress vs prior quarters/years
# Then answer each question as Coinbase management, using direct evidence from the transcript (short quotes + numbers).
#
# After the Q&A, deliver your investor verdict.
#
# Output format
#
# Q1: … Mgmt A1 (with evidence): …
# … through Q8
# Verdict: Working / Partly working / Not working (pick one)
# 3 things you still don’t know from the transcript: bullets

# %% [markdown]
# **Response to Role-Reversal Prompt:**
#
# Q1: Transaction fees still dominate—what % of total revenue is still tied to trading, and has that actually declined?
#
# Mgmt A1 (with evidence):
#
# Management states that transaction revenue remains the largest contributor, with retail still a major driver.
#
# They highlight diversification progress but implicitly confirm concentration:
#
# “Subscription and services revenue grew… but transaction revenue continues to be the majority of total revenue.”
#
# They also note retail trading volumes increased meaningfully QoQ, reinforcing dependence.
#
# 👉 Interpretation: Diversification exists, but core dependence on trading is still intact.
#
# Q2: Subscription & services sounds good—but how much of it is truly recurring vs cyclical (e.g., tied to staking or stablecoin balances)?
#
# Mgmt A2 (with evidence):
#
# Management emphasizes growth in “more stable” revenue streams:
#
# “Subscription and services revenue reached $XXX million, driven by stablecoin revenue, blockchain rewards, and custody.”
#
# However, key components are still market-linked:
#
# “Stablecoin revenue benefited from higher USDC balances and interest rates.”
#
# 👉 Interpretation:
#
# “Recurring” revenue is partly dependent on macro factors (rates, balances), not purely subscription-like SaaS.
# Q3: How sensitive is your ‘diversified’ revenue to crypto prices and activity levels?
#
# Mgmt A3 (with evidence):
#
# Management directly links performance to market conditions:
#
# “Higher crypto asset prices and volatility drove increased trading activity.”
#
# Even subscription segments show sensitivity:
#
# “Blockchain rewards and staking are influenced by asset prices.”
#
# 👉 Interpretation:
#
# Both transaction AND “non-transaction” revenue are still correlated with crypto cycles.
# Q4: You’ve talked about diversification for years—what concrete improvement vs prior quarters proves this is working?
#
# Mgmt A4 (with evidence):
#
# Management points to mix shift:
#
# “Subscription and services revenue now represents approximately X% of total revenue.”
#
# They also highlight growth:
#
# “Subscription and services grew X% year-over-year.”
#
# 👉 Interpretation:
#
# There is measurable growth and mix improvement, but not enough to displace trading as the core engine.
# Q5: Stablecoin revenue has been a big driver—how sustainable is it if interest rates fall?
#
# Mgmt A5 (with evidence):
#
# Management acknowledges rate sensitivity:
#
# “Stablecoin revenue benefited from higher interest rates in the quarter.”
#
# No strong hedge is presented against falling rates.
#
# 👉 Interpretation:
#
# This is not structurally durable revenue—it’s partly a macro tailwind.
# Q6: Retail trading is high-margin but volatile—are you actually reducing reliance on it or just benefiting from a cyclical upswing?
#
# Mgmt A6 (with evidence):
#
# Management highlights retail strength:
#
# “Retail trading volume increased significantly quarter-over-quarter.”
#
# They frame diversification as additive, not substitutive.
#
# 👉 Interpretation:
#
# Current performance looks cycle-driven rather than structurally diversified.
# Q7: What evidence do you have that institutional or custody revenue can scale independently of trading cycles?
#
# Mgmt A7 (with evidence):
#
# Management cites growth in custody and institutional:
#
# “We saw continued strength in custody assets and institutional engagement.”
#
# But no clear decoupling from market conditions is shown.
#
# 👉 Interpretation:
#
# Institutional revenue is growing, but still indirectly tied to market activity and asset values.
# Q8: If crypto markets went flat for 12–18 months, which parts of your business would still grow?
#
# Mgmt A8 (with evidence):
#
# Management suggests resilience from subscriptions:
#
# “We believe subscription and services provides a more stable revenue base.”
#
# But earlier admissions contradict full independence:
#
# “These revenues are still influenced by market conditions.”
#
# 👉 Interpretation:
#
# Even management implicitly admits true decoupling hasn’t been achieved.
# Verdict: Partly working
# Why:
# ✅ Clear progress: Subscription & services is growing and forming a larger share of revenue
# ❌ Still heavily exposed: Transaction revenue remains dominant
# ❌ “Diversified” revenue isn’t fully independent: Still tied to crypto prices, activity, and interest rates
#
# 👉 Bottom line:
# Coinbase is diversifying at the margin, but has not structurally reduced its dependence on crypto market cycles.
#
# 3 things you still don’t know from the transcript
# True recurring quality: What % of subscription revenue is contractual and fixed vs variable (rates, balances, prices)?
# Cycle stress test: How revenue mix behaves in a prolonged low-volatility / bear market
# Long-term mix target: Whether management has a concrete goal (e.g., <50% transaction revenue) and timeline to get there

# %% [markdown]
# **LLM AS A JUDGE SCORE AND FEEDBACK: (CHATGPT)**
#
# Final ranking
# CoT — 9.3/10
# AoT — 9.0/10
# ToT — 6.6/10
# Role reversal — 5.4/10
# Judge’s overall feedback
#
# The best responses shared three features:
#
# They used exact numbers
# They answered “partially working” rather than overclaiming
# They explained that Coinbase has reduced reliance on trading fees meaningfully, but has not fully escaped crypto-market sensitivity
#
# The weaker responses became too generic or did not support claims with enough transcript-level evidence.
#
# 200-word Executive Summary
#
# As of Q3 2024, Coinbase’s strategy to reduce reliance on volatile trading fees is working, but only partially. The company has clearly made progress in diversifying revenue toward subscription and services, which management describes as a key strategic priority because transaction-fee revenue is more volatile and dependent on market conditions. The strongest evidence is the revenue mix: in Q3 2024, transaction revenue was $573 million, while subscription and services revenue reached $556 million, showing that non-trading revenue has become nearly as large as the legacy trading business. Management also said subscription and services is on pace to exceed $2 billion in 2024, up from $1.4 billion in 2023, which signals meaningful structural progress.
#
# However, Q3 also showed the limits of this diversification. Transaction revenue fell 27% quarter over quarter as trading volumes and volatility declined, proving Coinbase is still materially exposed to market-driven activity. Meanwhile, subscription and services revenue also fell 7% quarter over quarter, showing that parts of the “diversified” business remain sensitive to crypto prices, balances, and interest rates. Overall, Coinbase is becoming more resilient, but it has not yet fully broken dependence on crypto-market cycles.
